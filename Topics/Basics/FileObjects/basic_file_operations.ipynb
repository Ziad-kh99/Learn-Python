# %%
# Open a file:
# file modes: read('r'), write('w'), append('a')

# file = open('text_copy.txt', 'r')
# cont = file.read()
# file.close()
# print(cont)

with open('text.txt', 'r') as f:
    # content = f.read()
    lst_cont = f.readlines()

# print(content)
print(lst_cont)
# Out:
# ['1) This is a test file!\n', '2) With multiple lines of data...\n', '3) Third line\n', '4) Fourth line\n', '5) Fifth line\n', '6) Sixth line']

# %%
# Write in a file:

fs = open('script.sh', 'w')
fs.write('!#/bin/bash')
fs.flush()      # to imidiatly write in the file & don't wait until to close it.
fs.close()


# with open('text2.txt', 'w') as fs:
#     fs.write('first statement in the file..')

# %%
# Append in a file:

with open('text_copy.txt', 'a') as fs:
    fs.write('7) Seventh line.\n')
    fs.write('8) Eighth line\n')
    print(fs.name)
    print(fs.closed)
# Out:
# text_copy.txt
# False
