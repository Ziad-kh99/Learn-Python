# %%
# Basic file-system operations:

from os import *

# make directory:
# mkdir('empty_dir')

# navigate to dir:
# chdir("empty_dir")

# mkdir('new_dir')
# chdir('../')

# Rename a file:
# rename('script2.sh', 'script.sh')

# Remove a file:
#remove('script.sh')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 20
#       3 from os import *
#       5 # make directory:
#       6 # mkdir('empty_dir')
#       7
#    (...)     17 # Remove a file:
#      18 #remove('script.sh')
# ---> 20 touch('file.txt')
#
# NameError: name 'touch' is not defined
